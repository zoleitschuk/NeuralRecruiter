# %%
def return_digits_only(input_str):
    output_str = ''.join([i for i in input_str if i.isdigit()])
    
    return output_str

# %%
def return_date_posted_appl(input_date_str):
    
    date_str = input_date_str.strip('Posted: ')
    
    return date_str

def get_apple_job_data(html):
    
    from bs4 import BeautifulSoup
    
    job_data_dict = {'job_title':'', 'ref_number':'', 'date_posted':'', 'location':''}

    soup = BeautifulSoup(html, 'html.parser')
    
    data_table = soup.find(class_="sosumi").find_all('li')
    
    job_data_dict['job_title'] = soup.h2.get_text()
    job_data_dict['ref_number'] = return_digits_only(data_table[0].get_text())
    job_data_dict['date_posted'] = return_date_posted_appl(data_table[2].get_text())
    job_data_dict['location'] = data_table[1].get_text()
    
    return job_data_dict

# %%
def get_intui_surgic_job_data(html):
    
    from bs4 import BeautifulSoup
    
    job_data_dict = {'job_title':'', 'ref_number':'', 'date_posted':'', 'location':''}
    
    soup = BeautifulSoup(html, 'html.parser')
        
    job_data_dict['job_title'] = soup.find(id='requisitionDescriptionInterface.reqTitleLinkAction.row1').get_text()
    job_data_dict['ref_number'] = soup.find(id='requisitionDescriptionInterface.reqContestNumberValue.row1').get_text()
    job_data_dict['date_posted'] = ''
    job_data_dict['location'] = soup.find(id='requisitionDescriptionInterface.ID1614.row1').get_text()
    
    return job_data_dict

# %%
def get_udacity_job_data(html):
    
    from bs4 import BeautifulSoup
    
    job_data_dict = {'job_title':'', 'ref_number':'', 'date_posted':'', 'location':''}
    
    soup = BeautifulSoup(html, 'html.parser')
        
    job_data_dict['job_title'] = soup.find(class_="posting-headline").h2.get_text()
    job_data_dict['ref_number'] = ''
    job_data_dict['date_posted'] = ''
    job_data_dict['location'] = soup.find(class_="sort-by-time posting-category medium-category-label").get_text()
    
    return job_data_dict

# %%
def get_tesla_motors_job_data(html):
    
    from bs4 import BeautifulSoup
    
    job_data_dict = {'job_title':'', 'ref_number':'', 'date_posted':'', 'location':''}
    
    soup = BeautifulSoup(html, 'html.parser')
        
    job_data_dict['job_title'] = soup.h1.get_text()
    job_data_dict['ref_number'] = soup.find_all(class_="formFieldNormal top")[0].get_text()
    job_data_dict['date_posted'] = ''
    job_data_dict['location'] = soup.find_all(class_="formFieldNormal top")[1].get_text()
    
    return job_data_dict

# %%
def get_google_job_data(html):
    
    from bs4 import BeautifulSoup
    
    job_data_dict = {'job_title':'', 'ref_number':'', 'date_posted':'', 'location':''}
    
    soup = BeautifulSoup(html, 'html.parser')
        
    job_data_dict['job_title'] = soup.find(itemprop="name title").get_text()
    job_data_dict['ref_number'] = ''
    job_data_dict['date_posted'] = soup.find(itemprop="datePosted").get_text()
    job_data_dict['location'] = soup.find(itemprop="name").get_text()
    
    return job_data_dict

# %%
def get_job_data(jobs_df):
    """
    Update jobs_df with the fields job_title, ref_number, date_posted, and location.
    These values will be scraped from the field job_desc_html. How the data is
    scraped will depend on the layout of the html. html layout is dependent on the 
    company.
    """
    import pandas as pd
    
    job_data_list = []
    
    for i in range(len(jobs_df['job_desc_html'])):
        
        job_data_dict = {'job_title':'', 'ref_number':'', 'date_posted':'', 'location':''}
        
        if(jobs_df.iloc[i]['company'] == 'Apple'):
            job_data_dict = get_apple_job_data(jobs_df.iloc[i]['job_desc_html'])
            
        elif(jobs_df.iloc[i]['company'] == 'Intuitive Surgical'):
            job_data_dict = get_intui_surgic_job_data(jobs_df.iloc[i]['job_desc_html'])
        
        elif(jobs_df.iloc[i]['company'] == 'Udacity'):
            job_data_dict = get_udacity_job_data(jobs_df.iloc[i]['job_desc_html'])
            
        elif(jobs_df.iloc[i]['company'] == 'Tesla Motors'):
            job_data_dict = get_tesla_motors_job_data(jobs_df.iloc[i]['job_desc_html'])
            
        elif(jobs_df.iloc[i]['company'] == 'Google'):
            job_data_dict = get_google_job_data(jobs_df.iloc[i]['job_desc_html'])
        
        job_data_list.append(job_data_dict)
    
    return pd.DataFrame(job_data_list)

# %%
def load_jobs_from_html(job_path):
    
    from bs4 import BeautifulSoup
    import pandas as pd

    # Use Beautiful soup constructor to parse through the html and build a more organized data structure.    
    try:
        html = open(job_path, encoding="utf8")
    except:
        raise
    else:
        html = open(job_path)
        
    soup = BeautifulSoup(html.read(), 'html.parser')
    html_list = []
    
    for child in soup.children:
        if(child.name):
            html_list.append((str(child),child.get_text()))
    
    return pd.DataFrame(html_list, columns=['job_desc_html', 'job_desc_text'])

# %%
if __name__ == "__main__":
    
    import sql_pandas
    
    file_path = input('Please enter the file path of the file containing'
                       ' the html you would like to add to the library.\n')
    new_jobs_df = load_jobs_from_html(file_path)
    
    company =  input('Please enter the company name associated with the file.\n')
    new_jobs_df['company'] = company
    
    # Execute main content.
    print(get_job_data(new_jobs_df))
# Out:
# Please enter the file path of the file containing the html you would like to add to the library.
# C:\Users\Zach\OneDrive\__Code\Projects\Job Hunter\data\input_data\google.html
# Please enter the company name associated with the file.
# Google
#       date_posted                                          job_title  \
# 0    Aug 16, 2016  Mechanical Engineer, Neuromodulation, Verily L...
# 1    Jul 13, 2016                                EMC Design Engineer
# 2    Jul 13, 2016  Software Prototyping Engineer, Project Aura, G...
# 3    Jul 13, 2016  Software Engineer, Virtual Reality Camera Systems
# 4    Aug 31, 2016          Hardware Lead Engineer, Consumer Hardware
# 5    Jul 13, 2016       Hardware Systems Engineer, Consumer Hardware
# 6    Dec 29, 2015  Data Center Facilities Technician/Engineer, Ta...
# 7    Jul 12, 2016                      Data Center Controls Engineer
# 8    Jul 15, 2016                            Systems Engineer, Tango
# 9    Jul 13, 2016       Data Center Controls and Automation Engineer
# 10   Aug 19, 2016                  Product Design Manager, Wearables
# 11   Sep 16, 2016                     Electrical Engineer, Wearables
# 12   Aug 13, 2016            Reliability Engineer, Consumer Hardware
# 13   Jul 13, 2016               Data Center Control Systems Engineer
# 14   Jul 13, 2016                Hardware System Validation Engineer
# 15   Jul 19, 2016                   Supplier Development Engineer, X
# 16   Jul 13, 2016               Safety Engineer, Hardware Operations
# 17   Sep 20, 2016                     Imaging Hardware Test Engineer
# 18   Sep 16, 2016  Hardware Test Engineer, Process Engineering, N...
# 19   Aug 12, 2016  Radio-Frequency/High-Speed Digital Hardware De...
# 20   Jul 12, 2016          Systems Engineer, Simulations (Makani), X
# 21   Jul 13, 2016  Manufacturing Test Engineer (Self-Driving Car), X
# 22   Jul 13, 2016           Quality Systems Specialist, Project Aura
# 23   Jul 13, 2016  Manager, Advanced Technology and Concept Engin...
# 24   Jul 15, 2016     Hardware Engineering Lead (Project Soli, ATAP)
# 25   Aug 26, 2016      Technical Program Manager, Developer Products
# 26   Mar 29, 2016                      Real Estate Project Executive
# 27   Aug 24, 2016  Software Manufacturing Test Engineer, Verily L...
# 28   Sep 09, 2016       Battery Hardware Engineer, Consumer Hardware
# 29   Jul 13, 2016                          Lead Reliability Engineer
# 30   Aug 17, 2016  Manufacturing Development Engineer, Lidar Sens...
# 31   Sep 13, 2016                         Principal Quality Engineer
# 32   Jul 13, 2016  Manufacturing Supplier Quality Engineer (Self-...
# 33   Aug 16, 2016     Product Development Lead, Verily Life Sciences
# 34   Jul 13, 2016         CAD/PCB Design Engineer, Consumer Hardware
# 35   Jul 13, 2016  Advanced Technology Process Development Engine...
# 36   Jul 30, 2016  Data Center Facilities Electrical Engineer/Tec...
# 37   Aug 27, 2016   Product Design Engineer (Project Jacquard, ATAP)
# 38   Jul 15, 2016          Device Calibration System Engineer, Tango
# 39   Sep 16, 2016         Data Center Facilities Technician/Engineer
# 40   Jul 13, 2016  Packaging Design Engineer, Project Aura, Glass...
# 41   Jul 13, 2016         Product Design Engineer, Consumer Hardware
# 42   Aug 18, 2016                 Product Design Engineer, Wearables
# 43   Aug 17, 2016            Product Design Engineer Lead, Wearables
# 44   Aug 13, 2016               Product Design Engineer, Living Room
# 45   Sep 16, 2016  Process Engineer, Neuromodulation, Verily Life...
# 46   Jul 13, 2016  Manufacturing Process Engineer (Self-Driving C...
# 47   Jul 13, 2016  Manufacturing Engineer, Technical Operations, ...
# 48   Aug 25, 2016       Manufacturing Engineer, Verily Life Sciences
# 49   Aug 10, 2016  Data Center Facilities Mechanical Engineer/Tec...
# 50   Jul 12, 2016  Mechanical Engineer, Loads and Aeroelasticity ...
# 51   Aug 16, 2016  Mechanical Engineer, Wearables, Verily Life Sc...
# 52   Aug 20, 2016                         Mechanical Engineer (ATAP)
#
#                         location ref_number
# 0   South San Francisco, CA, USA
# 1         Mountain View, CA, USA
# 2         Mountain View, CA, USA
# 3         Mountain View, CA, USA
# 4         Mountain View, CA, USA
# 5         Mountain View, CA, USA
# 6        Changhua County, Taiwan
# 7                Dublin, Ireland
# 8         Mountain View, CA, USA
# 9         Mountain View, CA, USA
# 10        Mountain View, CA, USA
# 11        Mountain View, CA, USA
# 12        Mountain View, CA, USA
# 13        Mountain View, CA, USA
# 14        Mountain View, CA, USA
# 15        Mountain View, CA, USA
# 16        Mountain View, CA, USA
# 17        Mountain View, CA, USA
# 18        Mountain View, CA, USA
# 19        Mountain View, CA, USA
# 20              Alameda, CA, USA
# 21        Mountain View, CA, USA
# 22        Mountain View, CA, USA
# 23        Mountain View, CA, USA
# 24        Mountain View, CA, USA
# 25        Mountain View, CA, USA
# 26              Hyderabad, India
# 27  South San Francisco, CA, USA
# 28        Mountain View, CA, USA
# 29        Mountain View, CA, USA
# 30        Mountain View, CA, USA
# 31        Mountain View, CA, USA
# 32        Mountain View, CA, USA
# 33  South San Francisco, CA, USA
# 34        Mountain View, CA, USA
# 35        Mountain View, CA, USA
# 36                     Singapore
# 37        Mountain View, CA, USA
# 38        Mountain View, CA, USA
# 39      Santiago Province, Chile
# 40        Mountain View, CA, USA
# 41        Mountain View, CA, USA
# 42        Mountain View, CA, USA
# 43        Mountain View, CA, USA
# 44        Mountain View, CA, USA
# 45  South San Francisco, CA, USA
# 46        Mountain View, CA, USA
# 47        Mountain View, CA, USA
# 48  South San Francisco, CA, USA
# 49                     Singapore
# 50              Alameda, CA, USA
# 51  South San Francisco, CA, USA
# 52        Mountain View, CA, USA
